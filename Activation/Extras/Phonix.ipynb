# %%
import pandas as pd
import numpy as np
import requests

# %%
feed_version = ['106.0' , '106.1']
users = ['16b378a27891j67x4f57', 'ij988a2716b3767x4f57']

# %%
#define functions to get ads retrieved by spells
def query_phoenix(query=None, user='16b37891d1ax4f578a27', category_filter=None, location_filter=None, 
                  user_lat=None, user_lon=None, site='olx.co.za', n_results=100,
                  layout=None, sorting=None, bucket_size=None):
    """ This method generates a requests to query phoenix using the search API.
    Params
    ======
    - query: the search string, None for category browsing (default: None).
    - category_filter: id of the category to use as a filter (default: None).
    - location_filter: id of the location to use as a filter (default: None).
    - user_lat: latitude of the user location, useful for searching by 'current location' (default: None).
    - user_lon: longitude of the user location, useful for searching by 'current location' (default: None).
    - site: name of the site (e.g. 'olx.in', 'olx.com.pk', etc.) (default: 'olx.in' for India).
    - n_results: maximum number of ads to retrieve (default: 100).
    - layout: id of the layout to use (default: '100.5', see http://destiny.internal.apps.prd.ap-southeast-1.horizontals.olx.org/olxin/100.5).
    - sorting: sorting strategy, valid options are 'desc-relevance', 'desc-price', 'asc-price', 'desc-creation', and 'asc-distance' (default: None).
    - bucket_size: size of the proximity buckets (default: None, it doesn't seem to work!).
    """
    params = {
        'user': user,
        'size': str(n_results),
        'layout': str(layout),
        'facet_limit': 100,
        'location_facet_limit': 20,
    }
    
    if query:
        params['query'] = query
    
    if category_filter:
        params['category'] = str(category_filter)
        
    if location_filter:
        params['location'] = str(location_filter)
        
    if user_lat and user_lon:
        params['latitude'] = str(user_lat)
        params['longitude'] = str(user_lon)
    
    if sorting:
        params['sorting'] = sorting
        
    if bucket_size:
        params['bucket_size'] = bucket_size
    r = requests.get("https://www.{}/api/relevance/search?".format(site), params=params)
    
    
    return r.json()

# %%
def parse(response, location_jitter=False, jitter_stdev=1e-3):
    """Parses the phoenix response and creates a pandas dataframe containing the result of the search.
    Params:
    =======
    - response: json containing the phoenix response.
    - location_jitter: whether to add random noise to ads latitude and longitude or not (default: False).
    - jitter_stdev: if location_jitter is True, add random noise taken from gaussian(mean=0, stdev=jitter_stdev), (default: 1e-3). 
    """
    data = response['data']
    # parse sections
    sections = response['metadata']['sections']
    section_ids = []
    last_offset = 0
    section_name = 0
    for i, section in enumerate(sections):
        offset = section['offset']
        if offset > len(data):
            break
        section_ids.append(np.repeat(section_name, offset - last_offset))
        last_offset = offset
        section_name = section['id']
    section_ids.append(np.repeat(section_name, len(data) - last_offset))
    section_ids = np.concatenate(section_ids)
    # create list of results that will be used to create the pandas dataframe
    output = []
    for i, (result, section) in enumerate(zip(data, section_ids)):
        spell_name = "{} v{}".format(result['spell']['key'], result['spell']['version'])
        item_id = result['id']
        locations = result['locations'][0]
        if location_jitter:
            locations['lat'] += np.random.normal(0, jitter_stdev, 1)[0]
            locations['lon'] += np.random.normal(0, jitter_stdev, 1)[0]
        output.append((item_id, i+1, locations['lat'], locations['lon'], section, spell_name))
    return pd.DataFrame(output, columns=['item_id', 'rank', 'latitude', 'longitude', 'section', 'spell_name'])

# %%
df = pd.DataFrame(columns=['item_id', 'rank', 'latitude', 'longitude', 'section', 'spell_name' , 'feed'])
for user, version in zip(users, feed_version):
    response = query_phoenix(query='iphone xs', user=user, category_filter=84 , location_filter=5048 , layout=version)
    dfs = parse(response)
    dfs['feed'] = version
    df = df.append(dfs)

# %%
d1060 = df[(df['feed'] == '106.0') & (df['spell_name'] == 'SILENCE v2')][['item_id' , 'rank' , 'feed']]
d1061 = df[(df['feed'] == '106.1') & (df['spell_name'] == 'SILENCE v2')][['item_id' , 'rank' , 'feed']]

# %%
diffe = d1060.merge(d1061 , how='left' , on=['item_id'])
diffe['difference_position'] = np.abs(diffe['rank_y'] - diffe['rank_x'])
af = diffe.head(20)
af = af.replace({None: 'No aparecio'})
af.head(7)
# Out:
#       item_id rank_x feed_x rank_y feed_y difference_position
# 0  1060718958      3  106.0      3  106.1                   0
# 1  1060698944      4  106.0      7  106.1                   3
# 2  1060648663      5  106.0     10  106.1                   5
# 3  1060602792      6  106.0      8  106.1                   2
# 4  1060590082      7  106.0      5  106.1                   2
# 5  1060585499      8  106.0      9  106.1                   1
# 6  1060467433      9  106.0      4  106.1                   5

# %%
df[df['rank'] < 6]
# Out:
#       item_id rank   latitude  longitude section    spell_name   feed
# 0  1060822807    1 -33.967047  18.478682       0  CONFUSION v1  106.0
# 1  1060809105    2 -34.050313  18.589125       0  CONFUSION v1  106.0
# 2  1060718958    3 -33.924900  18.424100       0    SILENCE v2  106.0
# 3  1060698944    4 -33.879277  18.628731       0    SILENCE v2  106.0
# 4  1060648663    5 -33.924900  18.424100       0    SILENCE v2  106.0
# 0  1060822807    1 -33.967047  18.478682       0  CONFUSION v1  106.1
# 1  1060809105    2 -34.050313  18.589125       0  CONFUSION v1  106.1
# 2  1060718958    3 -33.924900  18.424100       0    SILENCE v2  106.1
# 3  1060467433    4 -33.813856  18.499775       0    SILENCE v2  106.1
# 4  1060590082    5 -33.813856  18.499775       0    SILENCE v2  106.1

# %%
for version in feed_version:
    print(query_phoenix(query='cars' , category_filter=84 , location_filter=5048 , layout=version))
    df = parse(response)
    df['feed'] = version
# Out:
# {'version': '106.0', 'data': [{'id': '1060733874', 'score': 1.0, 'spell': {'key': 'DETECT_SECRET_DOORS', 'version': '1', 'main': False, 'id': 22}, 'status': {'status': 'active', 'allow_edit': True, 'ban_reason_id': None, 'display': 'active', 'translated_display': 'Active', 'link': None, 'flags': {'new': False, 'hot': False}, 'message': None}, 'favorites': {'count': 0, 'count_label_next': '1'}, 'location_source': None, 'has_phone_param': False, 'republish_date': None, 'created_at': '2019-10-24T16:54:47+02:00', 'description': 'FSH with agents and non agents... Car in side out in good condition... Tyres still very good... Few minor scratches... One remote key plus one service key...', 'title': '2008 Honda CR-V 2.0 RVSi with sunroof', 'partner_id': None, 'category_id': '378', 'price': {'key': 'price', 'key_name': 'Price', 'value': {'raw': 120000, 'display': 'R 120,000', 'currency': {'pre': 'R', 'iso_4217': 'ZAR'}}}, 'valid_to': '2020-01-13T14:53:51+02:00', 'partner_code': None, 'views': None, 'monetizationInfo': None, 'images': [{'id': '68817773', 'external_id': 'h2cdbkr204jh-ZA', 'width': 810, 'height': 1080, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/h2cdbkr204jh-ZA/image', 'full': {'width': 1080, 'height': 1440, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/h2cdbkr204jh-ZA/image;s=1080x1440'}, 'big': {'width': 505, 'height': 673, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/h2cdbkr204jh-ZA/image;s=505x673'}, 'medium': {'width': 120, 'height': 160, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/h2cdbkr204jh-ZA/image;s=120x160'}, 'small': {'width': 120, 'height': 160, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/h2cdbkr204jh-ZA/image;s=120x160'}}, {'id': '68817774', 'external_id': '4dfhmr7r2h6i2-ZA', 'width': 810, 'height': 1080, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/4dfhmr7r2h6i2-ZA/image', 'full': {'width': 1080, 'height': 1440, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/4dfhmr7r2h6i2-ZA/image;s=1080x1440'}, 'big': {'width': 505, 'height': 673, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/4dfhmr7r2h6i2-ZA/image;s=505x673'}, 'medium': {'width': 120, 'height': 160, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/4dfhmr7r2h6i2-ZA/image;s=120x160'}, 'small': {'width': 120, 'height': 160, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/4dfhmr7r2h6i2-ZA/image;s=120x160'}}, {'id': '68817775', 'external_id': 'qac3xdkf957h-ZA', 'width': 810, 'height': 1080, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/qac3xdkf957h-ZA/image', 'full': {'width': 1080, 'height': 1440, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/qac3xdkf957h-ZA/image;s=1080x1440'}, 'big': {'width': 505, 'height': 673, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/qac3xdkf957h-ZA/image;s=505x673'}, 'medium': {'width': 120, 'height': 160, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/qac3xdkf957h-ZA/image;s=120x160'}, 'small': {'width': 120, 'height': 160, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/qac3xdkf957h-ZA/image;s=120x160'}}, {'id': '68817776', 'external_id': '7xwm4hsy5qvt1-ZA', 'width': 810, 'height': 1080, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/7xwm4hsy5qvt1-ZA/image', 'full': {'width': 1080, 'height': 1440, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/7xwm4hsy5qvt1-ZA/image;s=1080x1440'}, 'big': {'width': 505, 'height': 673, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/7xwm4hsy5qvt1-ZA/image;s=505x673'}, 'medium': {'width': 120, 'height': 160, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/7xwm4hsy5qvt1-ZA/image;s=120x160'}, 'small': {'width': 120, 'height': 160, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/7xwm4hsy5qvt1-ZA/image;s=120x160'}}, {'id': '68817777', 'external_id': 'ipi7uhjttwt21-ZA', 'width': 810, 'height': 1080, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/ipi7uhjttwt21-ZA/imag ...
# {'version': '106.1', 'data': [{'id': '1060194230', 'score': 1.0, 'spell': {'key': 'DETECT_SECRET_DOORS', 'version': '1', 'main': False, 'id': 22}, 'status': {'status': 'active', 'allow_edit': True, 'display': 'active', 'translated_display': 'Active', 'flags': {'new': False, 'hot': False}}, 'favorites': {'count': 5, 'count_label': '5', 'count_label_next': '6', 'count_label_prev': '4'}, 'images': [{'id': '66171009', 'external_id': 'k9pu4oe4gpbk-ZA', 'width': 1080, 'height': 607, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/k9pu4oe4gpbk-ZA/image', 'full': {'width': 1080, 'height': 607, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/k9pu4oe4gpbk-ZA/image;s=1080x607'}, 'big': {'width': 505, 'height': 283, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/k9pu4oe4gpbk-ZA/image;s=505x283'}, 'medium': {'width': 120, 'height': 67, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/k9pu4oe4gpbk-ZA/image;s=120x67'}, 'small': {'width': 120, 'height': 67, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/k9pu4oe4gpbk-ZA/image;s=120x67'}}, {'id': '66171010', 'external_id': 'i8ph8bvog873-ZA', 'width': 1080, 'height': 607, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/i8ph8bvog873-ZA/image', 'full': {'width': 1080, 'height': 607, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/i8ph8bvog873-ZA/image;s=1080x607'}, 'big': {'width': 505, 'height': 283, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/i8ph8bvog873-ZA/image;s=505x283'}, 'medium': {'width': 120, 'height': 67, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/i8ph8bvog873-ZA/image;s=120x67'}, 'small': {'width': 120, 'height': 67, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/i8ph8bvog873-ZA/image;s=120x67'}}, {'id': '66171011', 'external_id': 't5jj1yj7tqb5-ZA', 'width': 1080, 'height': 607, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/t5jj1yj7tqb5-ZA/image', 'full': {'width': 1080, 'height': 607, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/t5jj1yj7tqb5-ZA/image;s=1080x607'}, 'big': {'width': 505, 'height': 283, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/t5jj1yj7tqb5-ZA/image;s=505x283'}, 'medium': {'width': 120, 'height': 67, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/t5jj1yj7tqb5-ZA/image;s=120x67'}, 'small': {'width': 120, 'height': 67, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/t5jj1yj7tqb5-ZA/image;s=120x67'}}, {'id': '66171012', 'external_id': '80q8r95xdpca-ZA', 'width': 1080, 'height': 607, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/80q8r95xdpca-ZA/image', 'full': {'width': 1080, 'height': 607, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/80q8r95xdpca-ZA/image;s=1080x607'}, 'big': {'width': 505, 'height': 283, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/80q8r95xdpca-ZA/image;s=505x283'}, 'medium': {'width': 120, 'height': 67, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/80q8r95xdpca-ZA/image;s=120x67'}, 'small': {'width': 120, 'height': 67, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/80q8r95xdpca-ZA/image;s=120x67'}}, {'id': '66171013', 'external_id': '2naprkwjnoqx2-ZA', 'width': 607, 'height': 1080, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/2naprkwjnoqx2-ZA/image', 'full': {'width': 1080, 'height': 1921, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/2naprkwjnoqx2-ZA/image;s=1080x1921'}, 'big': {'width': 505, 'height': 898, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/2naprkwjnoqx2-ZA/image;s=505x898'}, 'medium': {'width': 120, 'height': 213, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/2naprkwjnoqx2-ZA/image;s=120x213'}, 'small': {'width': 120, 'height': 213, 'url': 'https://apollo-ireland.akamaized.net:443/v1/files/2naprkwjnoqx2-ZA/image;s=120x213'}}, {'id': '66171014', 'external_id': 'qi0bn81t1g1d3-ZA', 'width': 1080, 'height': 607, 'url': 'https://apollo-ireland.akamaized.net:443/v1/fil ...

# %%
dfs
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Out:
#        item_id  rank   latitude  longitude  section              spell_name
# 0   1060750788     1 -33.810661  18.501593        0  DETECT_SECRET_DOORS v1
# 1   1060194230     2 -33.870815  18.700868        0  DETECT_SECRET_DOORS v1
# 2   1060823452     3 -33.882031  18.637104        0              SILENCE v2
# 3   1060823352     4 -33.949805  18.680038        0              SILENCE v2
# 4   1060165541     5 -33.953000  18.701000        0              SILENCE v2
# 5   1060823283     6 -34.033066  18.595433        0              SILENCE v2
# 6   1060823256     7 -34.033066  18.595433        0              SILENCE v2
# 7   1060823241     8 -33.907378  18.582732        0              SILENCE v2
# 8   1060823207     9 -33.990936  18.503905        0              SILENCE v2
# 9   1060823195    10 -33.935463  18.598265        0              SILENCE v2
# 10  1060823193    11 -33.922933  18.532133        0              SILENCE v2
# 11  1060823191    12 -33.884888  18.486214        0              SILENCE v2
# 12  1060823180    13 -33.936186  18.529492        0              SILENCE v2
# 13  1060823176    14 -33.922933  18.532133        0              SILENCE v2
# 14  1060823168    15 -34.047738  18.748217        0              SILENCE v2
# 15  1060823138    16 -33.920002  18.503036        0              SILENCE v2
# 16  1060823080    17 -34.016024  18.723274        0              SILENCE v2
# 17  1060823022    18 -33.899932  18.629680        0              SILENCE v2
# 18  1060823004    19 -34.075768  18.832963        0              SILENCE v2
# 19  1060822966    20 -34.051746  18.602719        0              SILENCE v2
# 20  1060663739    21 -33.827788  18.494468        0  DETECT_SECRET_DOORS v1
# 21  1060188464    22 -33.870771  18.700813        0  DETECT_SECRET_DOORS v1
# 22  1060822964    23 -33.937543  18.507586        0              SILENCE v2
# 23  1060822956    24 -33.937543  18.507586        0              SILENCE v2
# 24  1060822947    25 -33.959771  22.494362        0              SILENCE v2
# 25  1060822942    26 -33.937543  18.507586        0              SILENCE v2
# 26  1060822935    27 -33.949409  18.564869        0              SILENCE v2
# 27  1060822912    28 -33.894929  18.545906        0              SILENCE v2
# 28  1060822876    29 -33.994078  18.584655        0              SILENCE v2
# 29  1060822853    30 -33.942434  18.623615        0              SILENCE v2
# ..         ...   ...        ...        ...      ...                     ...
# 70  1060821471    71 -33.599250  22.224741        0              SILENCE v2
# 71  1060821433    72 -33.599250  22.224741        0              SILENCE v2
# 72  1060821373    73 -34.130000  18.861000        0              SILENCE v2
# 73  1060821349    74 -33.599250  22.224741        0              SILENCE v2
# 74  1060821327    75 -32.197579  18.896741        0              SILENCE v2
# 75  1060821309    76 -33.908163  18.573500        0              SILENCE v2
# 76  1060821235    77 -34.097703  18.853118        0              SILENCE v2
# 77  1060821232    78 -33.907378  18.582732        0              SILENCE v2
# 78  1060821173    79 -33.907378  18.582732        0              SILENCE v2
# 79  1060821093    80 -34.130000  18.861000        0              SILENCE v2
# 80  1060475842    81 -33.783362  18.455180        0  DETECT_SECRET_DOORS v1
# 81  1060797778    82 -33.918112  18.429105        0  DETECT_SECRET_DOORS v1
# 82  1060821087    83 -33.922933  18.532133        0              SILENCE v2
# 83  1060821076    84 -33.976665  18.502264        0              SILENCE v2
# 84  1060821064    85 -33.922933  18.532133        0              SILENCE v2
# 85  1060821049    86 -34.066205  18.615003        0              SILENCE v2
# 86  1060820940    87 -34.124133  18.387551        0              SILENCE v2
# 87  1060820935    88 -33.886306  18.697529        0              SILENCE v2
# 88  1060820928    89 -33.916779  18.429216        0              SILENCE v2
# 89  1060820880    90 -34.010301  18.509295        0              SILENCE v2
# 90  1060820842    91 -34.010301  18.509295        0              SILENCE v2
# 91  1060820736    92 -33.923744  18.439486        0              SILENCE v2
# 92  1060820731    93 -33.841972  18.715498        0              SILENCE v2
# 93  1060820675    94 -33.936186  18.529492        0              SILENCE v2
# 94  1060820660    95 -33.923744  18.439486        0              SILENCE v2
# 95  1060820584    96 -34.187357  22.135391        0              SILENCE v2
# 96  1060820581    97 -34.090713  18.844956        0              SILENCE v2
# 97  1060820543    98 -33.936168  18.655686        0              SILENCE v2
# 98  1060820503    99 -34.010301  18.509295        0              SILENCE v2
# 99  1060820499   100 -33.920002  18.503036        0              SILENCE v2
#
# [100 rows x 6 columns]

# %%
df.item_id.nunique()
# Out:
# 100
