# %% [markdown]
# # Connections

# %%
import pandas as pd
import numpy as np
from time import time
import json
from sqlalchemy import create_engine
import re
import datetime
import lifetimes
#import pymc3 as pm

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
plt.style.use('seaborn-whitegrid')
import numpy as np
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
import cufflinks
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)

from ipywidgets import interact

import plotly
plotly.tools.set_config_file(world_readable=False)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
connect = r"postgresql://{user}:{passw}@panamera-ods.cnsuxis6zqxr.us-west-2.redshift.amazonaws.com:5439/panameraods"
connection_string = connect.format(user='lucasdresl' , passw='cQsY801a76x82x62aWDT')

# %% [markdown]
# ## Login funnel buttons

# %% [markdown]
# - android for mea markets use base : panameraolx_mea_hydra_ninja_android_last_month
#     -  country_sk : olx|mea|pk , olx|mea|za , olx|mea|ng ...
# - android for india market use base : panameraolx_asia_hydra_ninja_android_last_month
#     -  country_sk : olx|asia|in

# %%
country_sk = 'olx|mea|za'

# %%
#############################################################################################
###################################### ANDROID ##############################################
#############################################################################################

query = """

WITH caso1delfunnel AS (

    SELECT 
           session,
           login_method
      from ods.panameraolx_mea_hydra_ninja_android_last_month
             WHERE (trackevent = 'login_sign_in_start')
                  and country_sk = 'olx|mea|za'
                  and date_event_nk != current_date
)
SELECT
  date_event_nk,
  login_method,
  COUNT(DISTINCT CASE WHEN trackevent = 'login_sign_in_start'    THEN session_long ELSE NULL END) AS show,
  COUNT(DISTINCT CASE WHEN trackevent = 'login_sign_in_complete' THEN session_long ELSE NULL END) AS login_complete
FROM ods.panameraolx_mea_hydra_ninja_android_last_month
JOIN caso1delfunnel USING (session,login_method)
  group by 1,2
  order by 2,1
  
"""

query2 = """

WITH caso1delfunnel AS (

    SELECT 
           session,
           login_method
      from ods.panameraolx_asia_hydra_ninja_android_last_month
             WHERE (trackevent = 'login_sign_in_start')
                  and country_sk = 'olx|asia|in'
                  and date_event_nk != current_date
)
SELECT
  date_event_nk,
  login_method,
  COUNT(DISTINCT CASE WHEN trackevent = 'login_sign_in_start'    THEN session_long ELSE NULL END) AS show,
  COUNT(DISTINCT CASE WHEN trackevent = 'login_sign_in_complete' THEN session_long ELSE NULL END) AS login_complete
FROM ods.panameraolx_asia_hydra_ninja_android_last_month
JOIN caso1delfunnel USING (session,login_method)
  where date_event_nk != current_date
  group by 1,2
  order by 2,1
  
"""

#############################################################################################
###################################### IOS ##################################################
#############################################################################################


query3 = """

WITH caso1delfunnel AS (

    SELECT 
           session,
           login_method
      from ods.panameraolx_mea_hydra_ninja_ios_last_month
             WHERE 
                 (trackevent = 'login_sign_in_start')
                  and country_sk = 'olx|mea|za'
                  and date_event_nk != current_date
)
SELECT
  date_event_nk,
  login_method,
  COUNT(DISTINCT CASE WHEN trackevent = 'login_sign_in_start'    THEN session_long ELSE NULL END) AS show,
  COUNT(DISTINCT CASE WHEN trackevent = 'login_sign_in_complete' THEN session_long ELSE NULL END) AS login_complete
FROM ods.panameraolx_mea_hydra_ninja_ios_last_month
JOIN caso1delfunnel USING (session,login_method)
where 
  date_event_nk != current_date
  group by 1,2
  order by 2,1
  
"""

query4 = """

WITH caso1delfunnel AS (

    SELECT 
           session,
           login_method
      from ods.panameraolx_asia_hydra_ninja_ios_last_month
             WHERE (trackevent = 'login_sign_in_start')
                  and country_sk = 'olx|asia|in'
                  and date_event_nk != current_date
)
SELECT
  date_event_nk,
  login_method,
  COUNT(DISTINCT CASE WHEN trackevent = 'login_sign_in_start'    THEN session_long ELSE NULL END) AS show,
  COUNT(DISTINCT CASE WHEN trackevent = 'login_sign_in_complete' THEN session_long ELSE NULL END) AS login_complete
FROM ods.panameraolx_asia_hydra_ninja_ios_last_month
JOIN caso1delfunnel USING (session,login_method)
  where date_event_nk != current_date
  group by 1,2
  order by 2,1
  
"""

#############################################################################################
###################################### PWA ##################################################
#############################################################################################

query5 = """

WITH caso1delfunnel AS (

    SELECT 
           session,
           login_method
      from ods.panameraolx_mea_hydra_ninja_web_last_month
             WHERE (trackevent = 'login_sign_in_start')
                  and country_sk = 'olx|mea|za'
                  and date_event_nk != current_date
)
SELECT
  date_event_nk,
  login_method,
  COUNT(DISTINCT CASE WHEN trackevent = 'login_sign_in_start'    THEN session_long ELSE NULL END) AS show,
  COUNT(DISTINCT CASE WHEN trackevent = 'login_sign_in_complete' THEN session_long ELSE NULL END) AS login_complete
FROM ods.panameraolx_mea_hydra_ninja_web_last_month
JOIN caso1delfunnel USING (session,login_method)
  where date_event_nk != current_date
  group by 1,2
  order by 2,1
  
"""

query6 = """

WITH caso1delfunnel AS (

    SELECT 
           session,
           login_method
      from ods.panameraolx_asia_hydra_ninja_web_last_month
             WHERE (trackevent = 'login_sign_in_start')
                  and country_sk = 'olx|asia|in'
                  and date_event_nk != current_date
)
SELECT
  date_event_nk,
  login_method,
  COUNT(DISTINCT CASE WHEN trackevent = 'login_sign_in_start'    THEN session_long ELSE NULL END) AS show,
  COUNT(DISTINCT CASE WHEN trackevent = 'login_sign_in_complete' THEN session_long ELSE NULL END) AS login_complete
FROM ods.panameraolx_asia_hydra_ninja_web_last_month
JOIN caso1delfunnel USING (session,login_method)
  where date_event_nk != current_date
  group by 1,2
  order by 2,1
  
"""

# %%
# %%time
df_matrix_mea_android = pd.read_sql_query(query.replace('%', '%%'), connection_string)
#df_matrix_asia_android = pd.read_sql_query(query2.replace('%', '%%'), connection_string)
df_matrix_mea_ios = pd.read_sql_query(query3.replace('%', '%%'), connection_string)
#df_matrix_asia_ios = pd.read_sql_query(query4.replace('%', '%%'), connection_string)
df_matrix_mea_web = pd.read_sql_query(query5.replace('%', '%%'), connection_string)
#df_matrix_asia_web = pd.read_sql_query(query6.replace('%', '%%'), connection_string)
# Out:
# Wall time: 2min 26s

# %%
df_matrix_mea_ios.tail()
# Out:
#     date_event_nk login_method  show  login_complete
# 166    2019-05-05          sms     2               0
# 167    2019-05-08          sms     1               1
# 168    2019-05-15          sms     1               0
# 169    2019-05-18          sms     1               0
# 170    2019-05-20          sms     1               1

# %%
#df_matrix_asia_android.drop(df_matrix_asia_android.tail(1).index,inplace=True)
#df_matrix_asia_android.tail()

#df_matrix_asia_android[df_matrix_asia_android['date_event_nk'] != '2019-05-03'].head(100)

# %%
df_matrix_mea_android['show_to_complete'] = df_matrix_mea_android['login_complete'] / df_matrix_mea_android['show']
#df_matrix_asia_android['show_to_complete'] = df_matrix_asia_android['login_complete'] / df_matrix_asia_android['show']

df_matrix_mea_ios['show_to_complete'] = df_matrix_mea_ios['login_complete'] / df_matrix_mea_ios['show']
#df_matrix_asia_ios['show_to_complete'] = df_matrix_asia_ios['login_complete'] / df_matrix_asia_ios['show']

df_matrix_mea_web['show_to_complete'] = df_matrix_mea_web['login_complete'] / df_matrix_mea_web['show']
#df_matrix_asia_web['show_to_complete'] = df_matrix_asia_web['login_complete'] / df_matrix_asia_web['show']

# %%
df_matrix_mea_web.to_excel('C:\\Users\\OLX - Lucas Dresi\\Documents\\Login\\login_za_pwa.xlsx')

# %%
df_matrix_mea_android['date_event_nk'] = pd.to_datetime(df_matrix_mea_android['date_event_nk'], format='%Y-%m-%d')
import datetime as dt
today = dt.datetime.today().strftime("%m/%d/%Y")
df_matrix_mea_android = df_matrix_mea_android.loc[(df_matrix_mea_android['date_event_nk'] < today)]

# %%
# Plot read time as a time series
df_matrix_mea_android[['date_event_nk', 'show_to_complete','login_method']].iplot(
                                                y='show_to_complete', 
                                                mode='lines',
                                                x='date_event_nk',
                                                xTitle='Date', 
                                                yTitle='show_to_complete',
                                                categories = 'login_method',
                                                title='South Africa Conversion from login start to login complete - Android')
# Out:
# <div>
#
#
#             <div id="0835bdb4-82f0-443f-adf4-7ebfba8ab2b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0835bdb4-82f0-443f-adf4-7ebfba8ab2b4")) {
#                     Plotly.newPlot(
#                         '0835bdb4-82f0-443f-adf4-7ebfba8ab2b4',
# ...

# %%
# Plot read time as a time series
df_matrix_asia_android[['date_event_nk', 'show_to_complete','login_method']].iplot(
                                                y='show_to_complete', 
                                                mode='lines+markers',
                                                x='date_event_nk',
                                                xTitle='Date', 
                                                yTitle='show_to_complete',
                                                categories = 'login_method',
                                                title='India Conversion from login start to login complete - Android')

# %%
# Plot read time as a time series
df_matrix_asia_ios[['date_event_nk', 'show_to_complete','login_method']].iplot(
                                                y='show_to_complete', 
                                                mode='lines+markers',
                                                x='date_event_nk',
                                                xTitle='Date', 
                                                yTitle='show_to_complete',
                                                categories = 'login_method',
                                                title='India Conversion from login start to login complete - IOS')

# %%
# Plot read time as a time series
df_matrix_mea_ios[['date_event_nk', 'show_to_complete','login_method']].iplot(
                                                y='show_to_complete', 
                                                mode='lines+markers',
                                                x='date_event_nk',
                                                xTitle='Date', 
                                                yTitle='show_to_complete',
                                                categories = 'login_method',
                                                title='South Africa Conversion from login start to login complete - IOS')
# Out:
# <div>
#
#
#             <div id="29766810-d61d-4c33-88b5-b4d5af2fd57e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("29766810-d61d-4c33-88b5-b4d5af2fd57e")) {
#                     Plotly.newPlot(
#                         '29766810-d61d-4c33-88b5-b4d5af2fd57e',
# ...

# %%
# Plot read time as a time series
df_matrix_mea_web[['date_event_nk', 'show_to_complete','login_method']].iplot(
                                                y='show_to_complete', 
                                                mode='lines+markers',
                                                x='date_event_nk',
                                                xTitle='Date', 
                                                yTitle='show_to_complete',
                                                categories = 'login_method',
                                                title='South Africa Conversion from login start to login complete - PWA')
# Out:
# <div>
#
#
#             <div id="04a0ab5e-d86f-467f-883a-494fd9f4659f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("04a0ab5e-d86f-467f-883a-494fd9f4659f")) {
#                     Plotly.newPlot(
#                         '04a0ab5e-d86f-467f-883a-494fd9f4659f',
# ...

# %%
# Plot read time as a time series
df_matrix_asia_web[['date_event_nk', 'show_to_complete','login_method']].iplot(
                                                y='show_to_complete', 
                                                mode='lines+markers',
                                                x='date_event_nk',
                                                xTitle='Date', 
                                                yTitle='show_to_complete',
                                                categories = 'login_method',
                                                title='India Conversion from login start to login complete - PWA')

# %% [markdown]
# # Trying to plotly dashboard

# %%
import plotly.dashboard_objs as dashboard

import IPython.display
from IPython.display import Image

my_dboard3 = dashboard.Dashboard()

# %%
# Android Pakistan
trace0 = go.Scatter(
             x=df_matrix_mea_android[(df_matrix_mea_android['login_method']=='email') ].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_mea_android[(df_matrix_mea_android['login_method']=='email')].show_to_complete,
             mode='lines+markers',
             name = 'email'        
        )

trace1 = go.Scatter(
             x=df_matrix_mea_android[(df_matrix_mea_android['login_method']=='phone')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_mea_android[(df_matrix_mea_android['login_method']=='phone')].show_to_complete,
             mode='lines+markers',
             name = 'phone'
)

trace2 = go.Scatter(
             x=df_matrix_mea_android[(df_matrix_mea_android['login_method']=='facebook')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_mea_android[(df_matrix_mea_android['login_method']=='facebook')].show_to_complete,
             mode='lines+markers',
             name = 'facebook'
)

trace3 = go.Scatter(
             x=df_matrix_mea_android[(df_matrix_mea_android['login_method']=='google')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_mea_android[(df_matrix_mea_android['login_method']=='google')].show_to_complete,
             mode='lines+markers',
             name = 'google'
)

data = [trace0,trace1,trace2,trace3]

layout = dict(title = 'Conversion of each method of login - Pakistan Android',
              yaxis = dict(title='Percentage' , zeroline = False),
              xaxis = dict(title='Date' , zeroline = False),
                           )

fig = dict(data=data, layout=layout)

# IPython notebook
py.iplot(fig, filename='conversion_login_method_android_mea')

url_1 = py.plot(fig, filename='conversion_login_method_android_mea', auto_open=False , sharing='secret')
url_1

# %%
# Android India
trace0 = go.Scatter(
             x=df_matrix_asia_android[(df_matrix_asia_android['login_method']=='email') ].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_asia_android[(df_matrix_asia_android['login_method']=='email')].show_to_complete,
             mode='lines+markers',
             name = 'email'        
        )

trace1 = go.Scatter(
             x=df_matrix_asia_android[(df_matrix_asia_android['login_method']=='phone')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_asia_android[(df_matrix_asia_android['login_method']=='phone')].show_to_complete,
             mode='lines+markers',
             name = 'phone'
)

trace2 = go.Scatter(
             x=df_matrix_asia_android[(df_matrix_asia_android['login_method']=='facebook')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_asia_android[(df_matrix_asia_android['login_method']=='facebook')].show_to_complete,
             mode='lines+markers',
             name = 'facebook'
)

trace3 = go.Scatter(
             x=df_matrix_asia_android[(df_matrix_asia_android['login_method']=='google')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_asia_android[(df_matrix_asia_android['login_method']=='google')].show_to_complete,
             mode='lines+markers',
             name = 'google'
)

data = [trace0,trace1,trace2,trace3]

layout = dict(title = 'Conversion of each method of login - India Android',
              yaxis = dict(title='Percentage' , zeroline = False),
              xaxis = dict(title='Date' , zeroline = False),
                           )

fig = dict(data=data, layout=layout)

# IPython notebook
py.iplot(fig, filename='conversion_login_method_android_asia')

url_2 = py.plot(fig, filename='conversion_login_method_android_asia', auto_open=False)
url_2

# %%
# IOS Pakistan
trace0 = go.Scatter(
             x=df_matrix_mea_ios[(df_matrix_mea_ios['login_method']=='email') ].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_mea_ios[(df_matrix_mea_ios['login_method']=='email')].show_to_complete,
             mode='lines+markers',
             name = 'email'        
        )

trace1 = go.Scatter(
             x=df_matrix_mea_ios[(df_matrix_mea_ios['login_method']=='phone')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_mea_ios[(df_matrix_mea_ios['login_method']=='phone')].show_to_complete,
             mode='lines+markers',
             name = 'phone'
)

trace2 = go.Scatter(
             x=df_matrix_mea_ios[(df_matrix_mea_ios['login_method']=='facebook')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_mea_ios[(df_matrix_mea_ios['login_method']=='facebook')].show_to_complete,
             mode='lines+markers',
             name = 'facebook'
)

trace3 = go.Scatter(
             x=df_matrix_mea_ios[(df_matrix_mea_ios['login_method']=='google')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_mea_ios[(df_matrix_mea_ios['login_method']=='google')].show_to_complete,
             mode='lines+markers',
             name = 'google'
)

data = [trace0,trace1,trace2,trace3]

layout = dict(title = 'Conversion of each method of login - Pakistan IOS',
              yaxis = dict(title='Percentage' , zeroline = False),
              xaxis = dict(title='Date' , zeroline = False),
                           )

fig = dict(data=data, layout=layout)

# IPython notebook
py.iplot(fig, filename='conversion_login_method_ios_mea')

url_3 = py.plot(fig, filename='conversion_login_method_ios_mea', auto_open=False )
url_3

# %%
# IOS India
trace0 = go.Scatter(
             x=df_matrix_asia_ios[(df_matrix_asia_ios['login_method']=='email') ].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_asia_ios[(df_matrix_asia_ios['login_method']=='email')].show_to_complete,
             mode='lines+markers',
             name = 'email'        
        )

trace1 = go.Scatter(
             x=df_matrix_asia_ios[(df_matrix_asia_ios['login_method']=='phone')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_asia_ios[(df_matrix_asia_ios['login_method']=='phone')].show_to_complete,
             mode='lines+markers',
             name = 'phone'
)

trace2 = go.Scatter(
             x=df_matrix_asia_ios[(df_matrix_asia_ios['login_method']=='facebook')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_asia_ios[(df_matrix_asia_ios['login_method']=='facebook')].show_to_complete,
             mode='lines+markers',
             name = 'facebook'
)

trace3 = go.Scatter(
             x=df_matrix_asia_ios[(df_matrix_asia_ios['login_method']=='google')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_asia_ios[(df_matrix_asia_ios['login_method']=='google')].show_to_complete,
             mode='lines+markers',
             name = 'google'
)

data = [trace0,trace1,trace2,trace3]

layout = dict(title = 'Conversion of each method of login - India IOS',
              yaxis = dict(title='Percentage' , zeroline = False),
              xaxis = dict(title='Date' , zeroline = False),
                           )

fig = dict(data=data, layout=layout)

# IPython notebook
py.iplot(fig, filename='conversion_login_method_ios_asia')

url_4 = py.plot(fig, filename='conversion_login_method_ios_asia', auto_open=False)
url_4

# %%
# PWA Pakistan
trace0 = go.Scatter(
             x=df_matrix_mea_web[(df_matrix_mea_web['login_method']=='email') ].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_mea_web[(df_matrix_mea_web['login_method']=='email')].show_to_complete,
             mode='lines+markers',
             name = 'email'        
        )

trace1 = go.Scatter(
             x=df_matrix_mea_web[(df_matrix_mea_web['login_method']=='phone')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_mea_web[(df_matrix_mea_web['login_method']=='phone')].show_to_complete,
             mode='lines+markers',
             name = 'phone'
)

trace2 = go.Scatter(
             x=df_matrix_mea_web[(df_matrix_mea_web['login_method']=='facebook')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_mea_web[(df_matrix_mea_web['login_method']=='facebook')].show_to_complete,
             mode='lines+markers',
             name = 'facebook'
)

trace3 = go.Scatter(
             x=df_matrix_mea_web[(df_matrix_mea_web['login_method']=='google')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_mea_web[(df_matrix_mea_web['login_method']=='google')].show_to_complete,
             mode='lines+markers',
             name = 'google'
)

data = [trace0,trace1,trace2,trace3]

layout = dict(title = 'Conversion of each method of login - Pakistan PWA',
              yaxis = dict(title='Percentage' , zeroline = False),
              xaxis = dict(title='Date' , zeroline = False),
                           )

fig = dict(data=data, layout=layout)

# IPython notebook
py.iplot(fig, filename='conversion_login_method_pwa_mea')

url_5 = py.plot(fig, filename='conversion_login_method_pwa_mea', auto_open=False )
url_5

# %%
# PWA India
trace0 = go.Scatter(
             x=df_matrix_asia_web[(df_matrix_asia_web['login_method']=='email') ].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_asia_web[(df_matrix_asia_web['login_method']=='email')].show_to_complete,
             mode='lines+markers',
             name = 'email'        
        )

trace1 = go.Scatter(
             x=df_matrix_asia_web[(df_matrix_asia_web['login_method']=='phone')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_asia_web[(df_matrix_asia_web['login_method']=='phone')].show_to_complete,
             mode='lines+markers',
             name = 'phone'
)

trace2 = go.Scatter(
             x=df_matrix_asia_web[(df_matrix_asia_web['login_method']=='facebook')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_asia_web[(df_matrix_asia_web['login_method']=='facebook')].show_to_complete,
             mode='lines+markers',
             name = 'facebook'
)

trace3 = go.Scatter(
             x=df_matrix_asia_web[(df_matrix_asia_web['login_method']=='google')].date_event_nk, # assign x as the dataframe column 'x'
             y=df_matrix_asia_web[(df_matrix_asia_web['login_method']=='google')].show_to_complete,
             mode='lines+markers',
             name = 'google'
)

data = [trace0,trace1,trace2,trace3]

layout = dict(title = 'Conversion of each method of login - India PWA',
              yaxis = dict(title='Percentage' , zeroline = False),
              xaxis = dict(title='Date' , zeroline = False),
                           )

fig = dict(data=data, layout=layout)

# IPython notebook
py.iplot(fig, filename='conversion_login_method_pwa_asia')

url_6 = py.plot(fig, filename='conversion_login_method_pwa_asia', auto_open=False)
url_6

# %%
import re

def fileId_from_url(url):
    """Return fileId from a url."""
    raw_fileId = re.findall("~[A-z]+/[0-9]+", url)[0][1: ]
    return raw_fileId.replace('/', ':')

fileId_1 = fileId_from_url(url_1)
fileId_2 = fileId_from_url(url_2)
fileId_3 = fileId_from_url(url_3)
fileId_4 = fileId_from_url(url_4)
fileId_5 = fileId_from_url(url_5)
fileId_6 = fileId_from_url(url_6)

# %%
box_a = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': fileId_1,
    'title': 'conversion_login_method_android_mea'
}

box_b = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': fileId_2,
    'title': 'conversion_login_method_android_asia'
}

box_c = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': fileId_3,
    'title': 'conversion_login_method_ios_mea'
}

box_d = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': fileId_4,
    'title': 'conversion_login_method_ios_asia'
}

box_e = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': fileId_5,
    'title': 'conversion_login_method_pwa_mea'
}

box_f = {
    'type': 'box',
    'boxType': 'plot',
    'fileId': fileId_6,
    'title': 'conversion_login_method_pwa_asia'
}

# %%
my_dboard3.insert(box_a, 'below', 1)

# %%
my_dboard3.insert(box_b, 'right', 1)

# %%
my_dboard3.insert(box_c, 'below', 1)

# %%
my_dboard3.insert(box_d, 'below', 3)

# %%
my_dboard3.insert(box_e, 'below', 2)

# %%
my_dboard3.insert(box_f, 'below', 5)

# %%
import plotly.plotly as py
py.dashboard_ops.upload(my_dboard3, 'Overall login conversion - Each button of login')

# %%
my_dboard3.remove(1)
